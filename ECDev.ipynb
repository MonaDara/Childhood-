# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA = pd.read_csv("C:/Users/Monica/Desktop/Early Childhood development data.csv")

# %%
N = pd.DataFrame(DATA)
N.round()
# Out:
#     用户            提交时间  来源  Age of mother in the time of conception?  \
# 0   匿名  1/1/2024 18:26  单聊                                        35
# 1   匿名  1/1/2024 18:39  单聊                                        25
# 2   匿名  1/2/2024 10:53  群聊                                        36
# 3   匿名  1/2/2024 11:03  群聊                                        39
# 4   匿名  1/2/2024 11:11  单聊                                        34
# 5   匿名  1/2/2024 11:11  群聊                                        30
# 6   匿名  1/2/2024 11:15  群聊                                        30
# 7   匿名  1/2/2024 11:55  群聊                                        33
# 8   匿名  1/2/2024 12:59  群聊                                        32
# 9   匿名  1/2/2024 17:34  群聊                                        32
# 10  匿名  1/2/2024 17:38  群聊                                        28
# 11  匿名  1/2/2024 17:51  群聊                                        34
# 12  匿名  1/2/2024 18:16  群聊                                        33
# ...

# %%
N.describe()
# Out:
#        Age of mother in the time of conception?  \
# count                                 25.000000
# mean                                  31.640000
# std                                    3.893156
# min                                   23.000000
# 25%                                   30.000000
# 50%                                   32.000000
# 75%                                   34.000000
# max                                   39.000000
#
#        Age of father in the time of conception?  Height of mother (cm)  \
# count                                 25.000000              25.000000
# mean                                  34.920000             163.000000
# std                                    5.837522               5.220153
# min                                   23.000000             155.000000
# 25%                                   32.000000             160.000000
# 50%                                   34.000000             164.000000
# ...

# %%
values = {"The height of child at the end of 24 months old.":88.771429, "The height of child at the end of 35 months old (cm), if applicable.":88.771429, "Baby’s Height at birth":50.545455}

# %%
Quality = {"Yes. More than two years":4, "Yes. Two years":3, "Yes. The first year":2, "No":1, "Before 18 months old": 1,
          "Around 27 months old":3,"Around 24 months old":2, "Around 30 months old":4, "After 36 months old":5,}
Qu= {"Only mother and father.":1,"Grandparents are involved as secondary caregivers":2,
          "The child had a nanny until 30 months old.":3,"The child has older siblings.":4, "The child has older siblings.\n& Only mother and father.":5,
          "The child had a nanny until 18 months old. & Grandparents are involved as secondary caregivers":6}

# %%
# import pandas library 
import pandas as pd 

# creating file handler for 
# our example.csv file in 
# read mode 
file_handler = open("C:/Users/Monica/Desktop/Early Childhood development data.csv", "r") 

# creating a Pandas DataFrame 
# using read_csv function 
# that reads from a csv file. 
data = pd.read_csv(file_handler, sep = ",") 

# closing the file handler 
file_handler.close() 

# creating a dict file 
VitaminD = {'No': 1,'Yes. The first year': 2, 'Yes. Two years':3,'Yes. More than two years':4} 

# traversing through dataframe 
# Gender column and writing 
# values where key matches 
data["Has the child taken Vitamin D? For how long?"] = [VitaminD[item] for item in data["Has the child taken Vitamin D? For how long?"]]
print(data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10052\3054932125.py in <module>
#      10 # using read_csv function
#      11 # that reads from a csv file.
# ---> 12 data = pd.read_csv(file_handler, sep = ",")
#      13
#      14 # closing the file handler
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df=N.fillna(values)
df
# Out:
#     用户            提交时间  来源  Age of mother in the time of conception?  \
# 0   匿名  1/1/2024 18:26  单聊                                        35
# 1   匿名  1/1/2024 18:39  单聊                                        25
# 2   匿名  1/2/2024 10:53  群聊                                        36
# 3   匿名  1/2/2024 11:03  群聊                                        39
# 4   匿名  1/2/2024 11:11  单聊                                        34
# 5   匿名  1/2/2024 11:11  群聊                                        30
# 6   匿名  1/2/2024 11:15  群聊                                        30
# 7   匿名  1/2/2024 11:55  群聊                                        33
# 8   匿名  1/2/2024 12:59  群聊                                        32
# 9   匿名  1/2/2024 17:34  群聊                                        32
# 10  匿名  1/2/2024 17:38  群聊                                        28
# 11  匿名  1/2/2024 17:51  群聊                                        34
# 12  匿名  1/2/2024 18:16  群聊                                        33
# ...

# %%
df5=N.replace(Quality)
df5
# Out:
#     用户            提交时间  来源  Age of mother in the time of conception?  \
# 0   匿名  1/1/2024 18:26  单聊                                        35
# 1   匿名  1/1/2024 18:39  单聊                                        25
# 2   匿名  1/2/2024 10:53  群聊                                        36
# 3   匿名  1/2/2024 11:03  群聊                                        39
# 4   匿名  1/2/2024 11:11  单聊                                        34
# 5   匿名  1/2/2024 11:11  群聊                                        30
# 6   匿名  1/2/2024 11:15  群聊                                        30
# 7   匿名  1/2/2024 11:55  群聊                                        33
# 8   匿名  1/2/2024 12:59  群聊                                        32
# 9   匿名  1/2/2024 17:34  群聊                                        32
# 10  匿名  1/2/2024 17:38  群聊                                        28
# 11  匿名  1/2/2024 17:51  群聊                                        34
# 12  匿名  1/2/2024 18:16  群聊                                        33
# ...

# %%
df.columns.tolist()
piechart = df.groupby(pd.Grouper(key="Child’s gender"), as_index=False).count()
from matplotlib.patches import ConnectionPatch
piechart.describe()
piechart.index
piechart.info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10052\158119936.py in <module>
# ----> 1 df.columns.tolist()
#       2 piechart = df.groupby(pd.Grouper(key="Child’s gender"), as_index=False).count()
#       3 from matplotlib.patches import ConnectionPatch
#       4 piechart.describe()
#       5 piechart.index
#
# NameError: name 'df' is not defined

# %%
fig, ax = plt.subplots()
ax.pie(piechart['The height of child at the end of 24 months old.'], labels=piechart['Child’s gender'], autopct='%1.1f%%')
plt.title("Gender Percentage",
     color = 'black', fontweight = 'bold', fontsize = '15')

plt.show()

helpin = df.groupby(pd.Grouper(key="Who helps the child with tooth brushing or potty training."), as_index=False).count()
fig, ax = plt.subplots()
ax.pie(helpin['The height of child at the end of 24 months old.'], labels=helpin['Who helps the child with tooth brushing or potty training.'], autopct='%1.1f%%')
plt.title("Who helps the child with tooth brushing or potty training.",
     color = 'black', fontweight = 'bold', fontsize = '15')

plt.show()

born = df.groupby(pd.Grouper(key="Baby was born Prem or term?"), as_index=False).count()
fig, ax = plt.subplots()
ax.pie(born['The height of child at the end of 24 months old.'], labels=born['Baby was born Prem or term?'], autopct='%1.1f%%')
plt.title("Baby was born Prem or term?",
     color = 'black', fontweight = 'bold', fontsize = '15')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10052\1098201378.py in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.pie(piechart['The height of child at the end of 24 months old.'], labels=piechart['Child’s gender'], autopct='%1.1f%%')
#       3 plt.title("Gender Percentage",
#       4      color = 'black', fontweight = 'bold', fontsize = '15')
#       5
#
# NameError: name 'piechart' is not defined

# %%
VD = df.groupby(pd.Grouper(key="Has the child taken Vitamin D? For how long?"), as_index=False).count()
Kinder = df.groupby(pd.Grouper(key="When did the child start going to the daycare/ kindergarten?"), as_index=False).count()
envir = df.groupby(pd.Grouper(key="Child environment"), as_index=False).count()

# %%
fig, ax = plt.subplots()
ax.pie(VD['The height of child at the end of 24 months old.'], labels=VD['Has the child taken Vitamin D? For how long?'], autopct='%1.1f%%')
plt.title("Has the child taken Vitamin D? For how long?",
     color = 'black', fontweight = 'bold', fontsize = '15')

plt.show()

fig, ax = plt.subplots()
ax.pie(Kinder['The height of child at the end of 24 months old.'], labels=Kinder['When did the child start going to the daycare/ kindergarten?'], autopct='%1.1f%%')
plt.title("When did the child start going to the daycare/ kindergarten?",
     color = 'black', fontweight = 'bold', fontsize = '15')

plt.show()

fig, ax = plt.subplots()
ax.pie(envir['The height of child at the end of 24 months old.'], labels=envir['Child environment'], autopct='%1.1f%%')
plt.title("Child environment",
     color = 'black', fontweight = 'bold', fontsize = '15')

plt.show()

# %%
VAD = df.groupby(pd.Grouper(key="Has the child taken Vitamin AD? For how long?"), as_index=False).count()
DHA = df.groupby(pd.Grouper(key="Has the child taken DHA? For how long?"), as_index=False).count()
Talk = df.groupby(pd.Grouper(key="When did the child start talking with steady development?"), as_index=False).count()

# %%
fig, ax = plt.subplots()
ax.pie(VAD['The height of child at the end of 24 months old.'], labels=VAD['Has the child taken Vitamin AD? For how long?'], autopct='%1.1f%%')
plt.title("Has the child taken Vitamin AD? For how long?",
     color = 'black', fontweight = 'bold', fontsize = '15')

plt.show()

fig, ax = plt.subplots()
ax.pie(DHA['The height of child at the end of 24 months old.'], labels=DHA['Has the child taken DHA? For how long?'], autopct='%1.1f%%')
plt.title("Has the child taken DHA? For how long?",
     color = 'black', fontweight = 'bold', fontsize = '15')

plt.show()

fig, ax = plt.subplots()
ax.pie(Talk['The height of child at the end of 24 months old.'], labels=Talk['When did the child start talking with steady development?'], autopct='%1.1f%%')
plt.title("When did the child start talking with steady development?",
     color = 'black', fontweight = 'bold', fontsize = '15')

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)
# pie chart parameters
fig, ax = plt.subplots()
overall_ratios = piechart['The height of child at the end of 24 months old.']
labels = piechart['Child’s gender']
explode = [0.1, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[1]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)
# bar chart parameters
height_ratios = [.27, .56, .1, .05]
height_labels = VAD['Has the child taken Vitamin AD? For how long?']
bottom = 1
width = .2
# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(height_ratios, height_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('Vitamin AD')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(height_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0,1])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0,1])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()

# %%
plt.figure(figsize=(10,4), dpi=80)
fg, ax = plt.subplots()
ax.pie(piechart['The height of child at the end of 24 months old.'], labels=piechart['Child’s gender'],autopct='%1.1f%%')
ax.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14028\2781500931.py in <module>
#       4 ax.axis('equal')
#       5 plt.show()
# ----> 6 plt.pie(df['The height of child at the end of 24 months old.'], df['Child’s gender'])
#       7 plt.xlabel('Loc')
#       8 plt.xticks(rotation = 90)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2754         textprops=None, center=(0, 0), frame=False,
#    2755         rotatelabels=False, *, normalize=True, data=None):
# -> 2756     return gca().pie(
#    2757         x, explode=explode, labels=labels, colors=colors,
#    2758         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ...

# %%
df2['Citations'].corr(df2['Score'])
# Out:
# -0.7863859284420089

# %%
import seaborn as sns

sns.heatmap(df.corr(), vmin=-1, vmax=1,
           annot=True, cmap="rocket_r")
plt.show()

# %%
plt.figure(figsize=(12,4), dpi=80)
plt.scatter(df['Child’s gender'], df['The height of child at the end of 24 months old.'], color = 'red')
plt.scatter(df['Child environment'], df['The height of child at the end of 24 months old.'], color = 'blue')
plt.scatter(df['Has the child taken DHA? For how long?'], df['The height of child at the end of 24 months old.'], color = 'green')
plt.scatter(df['Has the child taken Vitamin AD? For how long?'], df['The height of child at the end of 24 months old.'], color = 'yellow')
plt.scatter(df['Has the child taken Vitamin D? For how long?'], df['The height of child at the end of 24 months old.'], color = 'pink')
plt.scatter(df['Baby was born Prem or term?'], df['The height of child at the end of 24 months old.'], color = 'purple')
plt.xticks(rotation = 90)
plt.ylabel('height @ 24')
plt.show()
# Out:
# C:\Users\Monica\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(12,4), dpi=80)
plt.scatter(df5['Child’s gender'], df5['When did the child start talking with steady development?'], color = 'red')
plt.scatter(df5['Child environment'], df5['When did the child start talking with steady development?'], color = 'blue')
plt.scatter(df5['Has the child taken DHA? For how long?'], df5['When did the child start talking with steady development?'], color = 'green')
plt.scatter(df5['Has the child taken Vitamin AD? For how long?'], df5['When did the child start talking with steady development?'], color = 'yellow')


plt.xticks(rotation = 90)
plt.ylabel('Talk')
plt.show()

# %%
plt.figure(figsize=(12,4), dpi=80)
plt.scatter(df5['Has the child taken DHA? For how long?'], df5['When did the child start talking with steady development?'], color = 'green')
plt.scatter(df5['Has the child taken Vitamin AD? For how long?'], df5['When did the child start talking with steady development?'], color = 'yellow')
plt.scatter(df5['Has the child taken Vitamin D? For how long?'], df5['When did the child start talking with steady development?'], color = 'pink')



plt.xticks(rotation = 90)
plt.ylabel('Talk')
plt.show()

# %%
plt.figure(figsize=(12,4), dpi=80)
plt.scatter(df5['Who helps the child with tooth brushing or potty training.'], df5['When did the child start talking with steady development?'], color = 'purple')
plt.scatter(df5['Baby was born Prem or term?'], df5['When did the child start talking with steady development?'], color = 'orange')
plt.xticks(rotation = 90)
plt.ylabel('height @ 24')
plt.show()
# Out:
# C:\Users\Monica\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(12,4), dpi=80)
plt.scatter(df5['Age of mother in the time of conception?'], df5['When did the child start talking with steady development?'], color = 'pink')
plt.scatter(df5['Age of father in the time of conception?'], df5['When did the child start talking with steady development?'], color = 'blue')
plt.xlabel('Gender')
plt.xticks(rotation = 90)
plt.ylabel('height @ 24')
plt.show()

# %%
#sort with date time
df5.sort_values(by="When did the child start talking with steady development?")
# Out:
#     用户            提交时间  来源  Age of mother in the time of conception?  \
# 10  匿名  1/2/2024 17:38  群聊                                        28
# 21  匿名   1/6/2024 2:46  群聊                                        33
# 17  匿名  1/5/2024 15:51  单聊                                        36
# 15  匿名  1/2/2024 19:09  单聊                                        32
# 14  匿名  1/2/2024 19:05  群聊                                        30
# 13  匿名  1/2/2024 18:43  群聊                                        28
# 23  匿名  1/6/2024 10:17  群聊                                        25
# 20  匿名  1/5/2024 20:46  群聊                                        30
# 4   匿名  1/2/2024 11:11  单聊                                        34
# 3   匿名  1/2/2024 11:03  群聊                                        39
# 1   匿名  1/1/2024 18:39  单聊                                        25
# 9   匿名  1/2/2024 17:34  群聊                                        32
# 19  匿名  1/5/2024 19:00  群聊                                        31
# ...

# %%
df5.describe()
# Out:
#        Age of mother in the time of conception?  \
# count                                 25.000000
# mean                                  31.640000
# std                                    3.893156
# min                                   23.000000
# 25%                                   30.000000
# 50%                                   32.000000
# 75%                                   34.000000
# max                                   39.000000
#
#        Age of father in the time of conception?  Height of mother (cm)  \
# count                                 25.000000              25.000000
# mean                                  34.920000             163.000000
# std                                    5.837522               5.220153
# min                                   23.000000             155.000000
# 25%                                   32.000000             160.000000
# 50%                                   34.000000             164.000000
# ...

# %%
print("\n show the missing values of DataFrame:\n\n", df5.isnull().sum())
# Out:
#  show the missing values of DataFrame:
#
#  用户                                                                       0
# 提交时间                                                                     0
# 来源                                                                       0
# Age of mother in the time of conception?                                 0
# Age of father in the time of conception?                                 0
# Height of mother (cm)                                                    0
# Height of father (cm)                                                    0
# Child’s gender                                                           0
# Has the child taken Vitamin D? For how long?                             0
# Has the child taken Vitamin AD? For how long?                            0
# Has the child taken DHA? For how long?                                   0
# When did the child start going to the daycare/ kindergarten?             0
# ...

# %%
#df = df.astype({"Open":"int","High":"int","Low":"int","Close":"int","Adj Close":"int"})
print(df.dtypes)
# Out:
# World Rank                int64
# Institution              object
# Location                 object
# National Rank           float64
# Quality of Education    float64
# Alumni Employment       float64
# Quality of Faculty      float64
# Research Output         float64
# Quality Publications    float64
# Influence               float64
# Citations               float64
# Score                   float64
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14028\1678421800.py in <module>
#       1 plt.figure(figsize=(10,4), dpi=80)
#       2 fg, ax = plt.subplots()
# ----> 3 ax.piechart(pie['The height of child at the end of 24 months old.'], labels=pie.index,)
#       4 plt.pie(df2['Location'], df2['National Rank'])
#       5 plt.xlabel('Loc')
#
# AttributeError: 'AxesSubplot' object has no attribute 'piechart'

# %%
plt.figure(figsize=(10,7), dpi=80)
plt.scatter(df2['Research Output'], df2['Score'], color = 'b')
plt.scatter(df2['Influence'], df2['Score'], color = 'g')
plt.scatter(df2['Citations'], df2['Score'], color='red')
plt.xlabel('Citations=r/RO=b/Influence=g')
plt.xticks(rotation = 90)
plt.ylabel('Score')
plt.show()

# %%
Noise1 = df2[(df2["Research Output"]>120) & (df2["Score"]> 90)]
Noise1
# Out:
#    World Rank                         Institution Location  National Rank  \
# 6           7                Princeton University      USA              5
# 8           9  California Institute of Technology      USA              7
#
#    Alumni Employment  Research Output  Quality Publications  Influence  \
# 6                 15              146                    99         28
# 8                200              127                    81         13
#
#    Citations  Score
# 6         27   91.9
# 8         31   91.0

# %%
Noise2 = df2[(df2["Research Output"]>440) & (df2["Score"]> 80)]
Noise2
# Out:
#      World Rank                    Institution Location  National Rank  \
# 44           45  Weizmann Institute of Science   Israel              1
# 75           76         Rockefeller University      USA             44
# 115         116            École Polytechnique   France              5
# 116         117       École normale supérieure   France              6
#
#      Alumni Employment  Research Output  Quality Publications  Influence  \
# 44                1000              445                   292         69
# 75                1000              786                   434         32
# 115                  5              488                   396        348
# 116                627              598                   442        227
#
#      Citations  Score
# 44         254   84.9
# 75         275   82.7
# 115        254   80.9
# 116        460   80.8

# %%
Noise3 = df2[(df2["Citations"]<240) & (df2["Score"]<71)]
Noise3
# Out:
#      World Rank                                Institution Location  \
# 853         854  Federico Santa María Technical University    Chile
#
#      National Rank  Alumni Employment  Research Output  Quality Publications  \
# 853              4               1000             1000                  1000
#
#      Influence  Citations  Score
# 853       1000        222   70.7

# %%
Noise4 = df2[(df2["Citations"]>400) & (df2["Score"]>78)]
Noise4
# Out:
#      World Rank                                Institution Location  \
# 60           61             Hebrew University of Jerusalem   Israel
# 116         117                   École normale supérieure   France
# 188         189  University of Chinese Academy of Sciences    China
#
#      National Rank  Alumni Employment  Research Output  Quality Publications  \
# 60               2                400              177                   143
# 116              6                627              598                   442
# 188              6               1000               14                    37
#
#      Influence  Citations  Score
# 60         122        405   83.6
# 116        227        460   80.8
# 188        220        898   78.6

# %%
plt.figure(figsize=(10,5), dpi=80)
plt.bar(df2['National Rank'], df2['Score'], color = 'b')
plt.scatter(df2['World Rank'], df2['Score'], color='red')
plt.xlabel('WorldRank=r/NationalRank=b')
plt.grid()
plt.ylabel('Score')
plt.show()

# %%
plt.figure(figsize=(15,7), dpi=80)
plt.scatter(df2['Quality Publications'], df2['Score'], color = 'black')
plt.scatter(df2['Alumni Employment'], df2['Score'], color = 'pink')
plt.xlabel('QualityPub=black/ Alumni=pink')
plt.grid(
)
plt.ylabel('Score')
plt.show()

# %%
Noise5 = df2[(df2["Quality Publications"]>80) & (df2["Score"]>90)]
Noise5
# Out:
#    World Rank                         Institution Location  National Rank  \
# 6           7                Princeton University      USA              5
# 8           9  California Institute of Technology      USA              7
#
#    Alumni Employment  Research Output  Quality Publications  Influence  \
# 6                 15              146                    99         28
# 8                200              127                    81         13
#
#    Citations  Score
# 6         27   91.9
# 8         31   91.0

# %%
Noise6 = df2[(df2["Quality Publications"]>250) & (df2["Score"]>84)]
Noise6
# Out:
#     World Rank                    Institution Location  National Rank  \
# 44          45  Weizmann Institute of Science   Israel              1
#
#     Alumni Employment  Research Output  Quality Publications  Influence  \
# 44               1000              445                   292         69
#
#     Citations  Score
# 44        254   84.9

# %%
Noise7 = df2[(df2["Quality Publications"]>390) & (df2["Score"]>80)]
Noise7
# Out:
#      World Rank               Institution Location  National Rank  \
# 75           76    Rockefeller University      USA             44
# 115         116       École Polytechnique   France              5
# 116         117  École normale supérieure   France              6
#
#      Alumni Employment  Research Output  Quality Publications  Influence  \
# 75                1000              786                   434         32
# 115                  5              488                   396        348
# 116                627              598                   442        227
#
#      Citations  Score
# 75         275   82.7
# 115        254   80.9
# 116        460   80.8

# %%
df3 = df2.drop(index = [6,8,44,75,115,116])
df3
# Out:
#      World Rank                            Institution        Location  \
# 0             1                     Harvard University             USA
# 1             2                    Stanford University             USA
# 2             3  Massachusetts Institute of Technology             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5                   University of Oxford  United Kingdom
# ..          ...                                    ...             ...
# 995         996                    Aga Khan University        Pakistan
# 996         997                 University of Calcutta           India
# 997         998                       K?chi University           Japan
# 998         999               Soonchunhyang University     South Korea
# 999        1000              Capital Normal University           China
#
#      National Rank  Alumni Employment  Research Output  Quality Publications  \
# ...

# %%
plt.figure(figsize=(10,7), dpi=80)
plt.scatter(df4['Research Output'], df4['Score'], color = 'b')
plt.scatter(df4['Influence'], df4['Score'], color = 'g')
plt.scatter(df4['Citations'], df4['Score'], color='red')
plt.xlabel('Citations=r/RO=b/Influence=g')
plt.xticks(rotation = 90)
plt.ylabel('Score')
plt.show()

# %%
df4= df3.drop(index = [853,60,188])
df4
# Out:
#      World Rank                            Institution        Location  \
# 0             1                     Harvard University             USA
# 1             2                    Stanford University             USA
# 2             3  Massachusetts Institute of Technology             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5                   University of Oxford  United Kingdom
# ..          ...                                    ...             ...
# 995         996                    Aga Khan University        Pakistan
# 996         997                 University of Calcutta           India
# 997         998                       K?chi University           Japan
# 998         999               Soonchunhyang University     South Korea
# 999        1000              Capital Normal University           China
#
#      National Rank  Alumni Employment  Research Output  Quality Publications  \
# ...

# %%
plt.figure(figsize=(10,5), dpi=80)
plt.bar(df4['National Rank'], df4['Score'], color = 'b')
plt.scatter(df4['World Rank'], df4['Score'], color='red')
plt.xlabel('WorldRank=r/NationalRank=b')
plt.grid()
plt.ylabel('Score')
plt.show()

# %%
plt.figure(figsize=(15,7), dpi=80)
plt.scatter(df4['Quality Publications'], df4['Score'], color = 'black')
plt.scatter(df4['Alumni Employment'], df4['Score'], color = 'pink')
plt.xlabel('QualityPub=black/ Alumni=pink')
plt.grid(
)
plt.ylabel('Score')
plt.show()

# %%
plt.figure(figsize=(12,4), dpi=80)
plt.scatter(df['Location'], df['Score'], color = 'red')
plt.xlabel('Loc')
plt.xticks(rotation = 90)
plt.ylabel('Score')
plt.show()

# %%
plt.figure(figsize=(12,4), dpi=80)
plt.scatter(df['Location'], df['Citations'], color = 'green')
plt.xlabel('Loc')
plt.xticks(rotation = 90)
plt.ylabel('Citations')
plt.show()

# %%
plt.figure(figsize=(6,6), dpi=80)
plt.scatter(df4['Quality Publications'], df4['World Rank'], color = 'purple')
plt.xlabel('Quality Publications')
plt.xticks(rotation = 90)
plt.ylabel('World Rank')
plt.show()
sns.lmplot(x="Quality Publications", y="World Rank", data=df4)

# %%
plt.figure(figsize=(6,6), dpi=80)
plt.scatter(df4['Citations'], df4['World Rank'], color = 'purple')
plt.xlabel('Citations')
plt.xticks(rotation = 90)
plt.ylabel('World Rank')
plt.show()

# %%
plt.figure(figsize=(6,6), dpi=80)
plt.scatter(df['Alumni Employment'], df['World Rank'], color = 'purple')
plt.xlabel('Alumni Employment')
plt.xticks(rotation = 90)
plt.ylabel('World Rank')
plt.show()
sns.lmplot(x="Alumni Employment", y="World Rank", data=df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12892\4184622481.py in <module>
#       5 plt.ylabel('World Rank')
#       6 plt.show()
# ----> 7 sns.lmplot(x="Alumni Employment", y="World Rank", data=df2)
#
# NameError: name 'df2' is not defined

# %%
plt.figure(figsize=(6,6), dpi=80)
plt.scatter(df2['National Rank'], df2['World Rank'], color = 'purple')
plt.xlabel('National Rank')
plt.xticks(rotation = 90)
plt.ylabel('World Rank')
plt.show()

# %%
plt.figure(figsize=(6,6), dpi=80)
plt.scatter(df4['Influence'], df4['World Rank'], color = 'purple')
plt.xlabel('Influence')
plt.xticks(rotation = 90)
plt.ylabel('World Rank')
plt.show()
